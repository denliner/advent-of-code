# %%
#overkill but that work

import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=FutureWarning) 

# with open("shop.txt") as f:
#     shop=f.read().strip().replace(":","").split("\n\n")
#     shop=[x.splitlines() for x in shop]
#     shop=[[y.split() for y in x] for x in shop ]


with open("example.txt") as f:
    boss=f.read().strip().splitlines()
    boss=[x.split(": ") for x in boss]
    bossAttack=int(boss[1][1])
    bossHP=int(boss[0][1])
    ourHP=100
bossHP,bossAttack

# shopDF=pd.DataFrame(index=['Name','Type','Cost', 'Damage', 'Armor'])
# for elem in shop:
#     type=elem[0][0]
#     for e in elem[1:]:
#        # print("e:  ",e)
#         if(len(e)>4):
#             name=e[0]+" "+e[1]
#             cost=e[2]
#             damage=e[3]
#             armor=e[4]
#         else:
#             name=e[0]
#             cost=e[1]
#             damage=e[2]
#             armor=e[3]
#         shopDF = shopDF.append({'Name' : name, 'Type' : type, 
#                          'Cost' : cost, 'Damage' : damage,
#                          'Armor' : armor},ignore_index = True)


# shopDF=shopDF.dropna(subset=["Name"]).reset_index(drop=True)


# import itertools
# listOLists = [shopDF[shopDF["Type"]=="Weapons"].values.tolist(),
#               [["NaN"]*5]+shopDF[shopDF["Type"]=="Armor"].values.tolist(),
#               [["NaN"]*5]+shopDF[shopDF["Type"]=="Rings"].values.tolist(),
#               [["NaN"]*5]+shopDF[shopDF["Type"]=="Rings"].values.tolist()]
# combi=itertools.product(*listOLists,repeat=1)
# combi2=[]
# for i in combi:
#     dups = {tuple(x) for x in i if i.count(x)>1 and not x[0]=='NaN'}
#     if(not dups):
#         combi2.append(i)

# for i,elem in  enumerate(combi2):
#     combi2[i]=list(elem)
# for i,elem in  enumerate(combi2):
#     cost,fullAmor,fullAttack =0,0,0
#     for e in elem:
#         if(e[0]=="NaN"):
#             continue
#         cost+=int(e[2])
#         fullAmor+=int(e[4])
#         fullAttack+=int(e[3])
#     elem.insert(0,fullAmor)
#     elem.insert(0,fullAttack)
#     elem.insert(0,cost)


# combi2.sort()

# for elem in combi2:
#     turn2killB= (bossHP)//(elem[1] - bossArmor)
#     turn2killP= (ourHP)//(bossAttack - elem[2])
#     if(turn2killB<=turn2killP):
#         print("part 1:",elem[0])
#         break

# combi2.sort(reverse=True)

# for elem in combi2:
#     try:
#         turn2killB= (bossHP)//max(0,(elem[1] - bossArmor))
#     except ZeroDivisionError: 
#         turn2killB=float("inf")
        
#     try: 
#         turn2killP= (ourHP)// max(0,(bossAttack - elem[2]))
#     except ZeroDivisionError: 
#         turn2killP=float("inf")   
#     if(turn2killB>turn2killP):
#         print("part 2:",elem[0])
#         break
# Out:
# (13, 8)
