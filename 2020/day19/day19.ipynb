# %%
"1: 2 3 | 3 2"
'4: "a"'
def generate_rule(string,dictionary):
    s=string.split(": ")
    list_rules=[]
    if(any(char.isdigit() for char in s[1])):
        if("|" in s[1]):  
            rules=s[1].split(" | ")
            for r in rules:
                rule=r.split(" ")
                list_rules.append(rule)
        else:
            rule=s[1].split(" ")
            list_rules.append(rule)
    else:
        list_rules=s[1].replace('"', '')
    dictionary[s[0]]=list_rules
    return dictionary

def generate_all_rule(l_rules,dictionary):
    for rule in l_rules:
        generate_rule(rule,dictionary)
    return dictionary
    
def pseudo_BFS(string,dictionary,currentRule,n,P2):
    condition=False
    #print("rule="+str(currentRule))
    #print("n="+str(n)+"\n")
    if not type(dictionary[currentRule])==list:
        #print(string[n])
        return dictionary[currentRule]==string[n],n+1
    else:
        for elem in dictionary[currentRule]:
            #print("elem="+str(elem))
            #print("n before="+str(n))
            currentn=n
            for i,e in enumerate(elem):
                if(P2):
                    if(currentn>=len(string)):
                        print("current")
                        print(currentRule)
                        print("lenght")
                        print(len(elem)-1)
                        print("i")
                        print(i)
                        if(i==len(elem)-1):
                            return True,currentn
                        else:
                            return False,currentn
                #print("e="+str(e))
                check,nextN=pseudo_BFS(string,dictionary,e,currentn,P2)
                if(check):
                    #print("check")
                    condition=True
                    currentn=nextN
                else:
                    currentn=n
                    condition=False
                    break
                
            if(condition):
                #print("checked")
                #print("state="+str(currentRule))
                #print(currentn)
                break
            #print("|")
            currentn=n
    return condition,currentn
    
    

def generate_input(name):
    l_string = open(name).read().rstrip().replace("\n\n", "\t").replace("\n", "^").split("\t")
    l_string = [sub.split("^") for sub in l_string]
    #print(l_string)
    return l_string

def day19p1(l_string,l_rules):
    dictionary={}
    count=0
    generate_all_rule(l_rules,dictionary)
    for key in dictionary:
        print(""+str(key)+": "+ str(dictionary[key]))
    for string in l_string:
        check,n=pseudo_BFS(string,dictionary,'0',0,False)
        if(check):
            print(string)
            count+=1
    return count


def day19p2(l_string,l_rules):
    dictionary={}
    new_rule=['8: 42 | 42 8','11: 42 31 | 42 11 31']
    count=0
    generate_all_rule(l_rules,dictionary)
    #generate_all_rule(new_rule,dictionary)
    print(dictionary)
    for string in l_string:
        #print(string)
        check,n=pseudo_BFS(string,dictionary,'0',0,True)
        print("n="+str(n))
        if(check):
            print(string)
            count+=1
    return count

l_rules,l_string=generate_input('inputtest3.txt')
#print(l_rules)
#l_string
dictionary={}
new_rule=['8: 42 | 42 8','11: 42 31 | 42 11 31']
generate_all_rule(l_rules,dictionary)
#generate_all_rule(new_rule,dictionary)
for key in dictionary:
    print(""+key+":\t"+str(dictionary[key]))
"aaaabbaaaabbaaa"
print(pseudo_BFS("aaaabbaaaabbaaa",dictionary,'0',0,True))
#print(generate_rule("1: 2 3 | 3 2",{}))
#print(generate_rule('4: "a"',{}))
#"1: 2 3 | 3 2"
#type([2,2,3])==list
#print("count="+str(day19p1(l_string,l_rules)))
print("count="+str(day19p2(l_string,l_rules)))
#print(generate_input('input.txt')[1])
# Out:
# 42:	[['9', '14'], ['10', '1']]
# 9:	[['14', '27'], ['1', '26']]
# 10:	[['23', '14'], ['28', '1']]
# 1:	a
# 5:	[['1', '14'], ['15', '1']]
# 19:	[['14', '1'], ['14', '14']]
# 12:	[['24', '14'], ['19', '1']]
# 16:	[['15', '1'], ['14', '14']]
# 31:	[['14', '17'], ['1', '13']]
# 6:	[['14', '14'], ['1', '14']]
# 2:	[['1', '24'], ['14', '4']]
# 0:	[['8', '11']]
# 13:	[['14', '3'], ['1', '12']]
# 15:	[['1'], ['14']]
# 17:	[['14', '2'], ['1', '7']]
# 23:	[['25', '1'], ['22', '14']]
# 28:	[['16', '1']]
# 4:	[['1', '1']]
# 20:	[['14', '14'], ['1', '15']]
# 3:	[['5', '14'], ['16', '1']]
# 27:	[['1', '6'], ['14', '18']]
# 14:	b
# 21:	[['14', '1'], ['1', '14']]
# 25:	[['1', '1'], ['1', '14']]
# 22:	[['14', '14']]
# 8:	[['42'], ['42', '8']]
# 11:	[['42', '31'], ['42', '11', '31']]
# 26:	[['14', '22'], ['1', '20']]
# 18:	[['15', '15']]
# 7:	[['14', '5'], ['1', '21']]
# 24:	[['14', '1']]
# current
# 11
# lenght
# 1
# i
# 1
# current
# 11
# lenght
# 2
# i
# 2
# (True, 15)
# ...

# %%
for i in enumerate(l_string):
    print(i)
# Out:
# (0, 'abbbbbabbbaaaababbaabbbbabababbbabbbbbbabaaaa')
# (1, 'bbabbbbaabaabba')
# (2, 'babbbbaabbbbbabbbbbbaabaaabaaa')
# (3, 'aaabbbbbbaaaabaababaabababbabaaabbababababaaa')
# (4, 'bbbbbbbaaaabbbbaaabbabaaa')
# (5, 'bbbababbbbaaaaaaaabbababaaababaabab')
# (6, 'ababaaaaaabaaab')
# (7, 'ababaaaaabbbaba')
# (8, 'baabbaaaabbaaaababbaababb')
# (9, 'abbbbabbbbaaaababbbbbbaaaababb')
# (10, 'aaaaabbaabaaaaababaa')
# (11, 'aaaabbaaaabbaaa')
# (12, 'aaaabbaabbaaaaaaabbbabbbaaabbaabaaa')
# (13, 'babaaabbbaaabaababbaabababaaab')
# (14, 'aabbbbbaabbbaaaaaabbbbbababaaaaabbaaabba')

# %%
len("aabbbbbaabbbaaaaaabbbbbababaaaaabbaaabba")
# Out:
# 40

# %%
import re

def generate_rule(s,depth,ruledict):
    if(depth>FUCK_YOURSELF_ERIC):
        return ""
    depth+=1
    if(not any(char.isdigit() for char in s)):
        return s.replace('"', '')
    elif("|" in s):  
        rules1,rules2=s.split(" | ")
        return '('+generate_rule(rules1,depth,ruledict)+"|"+generate_rule(rules2,depth,ruledict)+")"
    elif(" " in s):
        split=s.split(" ")
        rule=""
        for r in split:
            rule+=generate_rule(r,depth,ruledict)
        return rule
    else:
        return generate_rule(ruledict[s],depth,ruledict)

def generate_input(name):
    l_string = open(name).read().rstrip().replace("\n\n", "\t").replace("\n", "^").split("\t")
    l_string = [sub.split("^") for sub in l_string]
    return l_string

def day19(l_string,l_rules):
    rule_dict=generate_dictionary(l_rules)
    regex=re.compile(generate_rule('0',0,rule_dict))
    count=0
    for string in l_string:
        if(regex.fullmatch(string)):
            count+=1
    return count


def generate_dictionary(l_rules):
    dictionary={}
    for rule in l_rules:
        split=rule.split(": ")
        dictionary[split[0]]=split[1]
    return dictionary

l_rules,l_string=generate_input("input.txt")
FUCK_YOURSELF_ERIC=len(max(l_string,key=len))
print("Part 1= "+str(day19(l_string,l_rules)))

l_rules,l_string=generate_input("input2.txt")
print("Part 2= "+str(day19(l_string,l_rules)))
# Out:
# Part 1= 210
# Part 2= 422
